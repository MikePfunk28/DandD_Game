# %% [markdown]
# Merry Thanksgiving everyone and here is your present!!
# One thing that bothers me the most, is that it is not so straightforward to practice development in AWS without incurring charges.  If I want to go about a set scenario, or if I am learning, the labs are great!
# However, I was demo'd the CloudHealth platform the other day and I saw the light.  I wanted to be able to dev without incurring charges, who doesn't?  I mean they must have a way to develop tools without going broke in the process, right??
# YES!!  There are multiple ways, and I am also sure you can figure out ways in your head, simulating, or emulating your env.  Using Docker, with LocalStack, or terraform, you can do that.  I would suggest the LocalStack docker extension, with Terraform.  Terraform is Infrastructure as Code, so you can automate your infrastructure.  LocalStack is for emulating your cloud environment locally.
# How it essentially works is you emulate the AWS services.  Instead of pointing at an AWS service on their cloud, you point to an endpoint configured local on your machine.
# endpoints {
#     s3 = "http://localhost:4566"
#     # Add other services as needed
#   }
# You create a main.tf file and that will be how LocalStack knows, after installing all three.  You need LocalStack, which uses docker, and then terraform will aid in automation.
# Here is the main.tf file I use for my terraform configuration.  You create that in the same directory as terraform.
# provider "aws" {
#   access_key                  = "test"
#   secret_key                  = "test"
#   region                      = "us-east-1"
#   s3_use_path_style           = true
#   skip_credentials_validation = true
#   skip_metadata_api_check     = true
#   skip_requesting_account_id  = true
#   endpoints {
#     s3 = "http://localhost:4566"
#     # Add other services as needed
#   }
# }
# After you created the main.tf file, which I would copy exactly an experiment later.  Run the command in that folder where you created main.tf, tflocal init.  This will attempt to initialize it in your local environment.
# From what I can tell, the code is mainly in python, so its interesting to see how they did it.  The last step is to run tflocal apply.  Then just take to make sure it works.
# You might need to set your environment variables in PATH, to where you install the .exe.  Follow the instructions on these pages below.  Personally, I have docker desktop installed.
# LocalStack Installation:
# Install LocalStack with Docker Extension:
# Docker Extension for LocalStack:
# The last thing is the link to the AWS documentation for testing infrastructure with LocalStack and terraform tests.
# I pretty much highlighted the parts that caused me some issues during setup.  However I would go through the documentation. (edited)
#
# DockerDocker
# Docker: Accelerated Container Application Development
# Docker is a platform designed to help developers build, share, and run container applications. We handle the tedious setup, so you can focus on the code.
# Written by
# Simeon Ratliff
# Time to read
# 28 minutes
# May 10th, 2022
# https://www.docker.com/
#
#
# DocsDocs
# AWS Service Feature Coverage
# Overview of the implemented AWS APIs and their level of parity with the AWS cloud
#
# DocsDocs
# Terraform
# Use the Terraform Infrastructure as Code framework with LocalStack
#
#
# Michael Pfundt
#   11:51 PM
# image.png
#
# image.png

# %% [markdown]
# Merry Thanksgiving everyone!!
#
# One thing that bothers me the most, is that it is not so straightforward to practice development in AWS without incurring charges. If I want to go about a set scenario, or if I am learning, the labs are great, and obviously Free Tier as well.
#
# Actually there is a way, create a test environment using Docker, Inc containers, LocalStack to emulate, and Terraform Labs to turn infrastructure into code.  I would suggest the LocalStack docker extension, with Terraform.
#
# You need to install Docker, I installed the desktop version, which has its own terminal. Then install Localstack, the cli is an executable, same with terraform.
#
# Essentially it works by emulating the AWS services.  Instead of pointing at an AWS service endpoint, you configure the endpoint to point at your localhost, on a port its expecting.
#
# ```json
# endpoints {
#  s3 = "http://localhost:4566"
#  # Add other services as needed
#  }
# ```
#
# LocalStack creates a backend and frontend, which has .env file you match to the main.tf file you create. That will be how LocalStack knows, after installing all three. You need LocalStack, which uses docker, and then terraform will aid in automation.
#
# Here is the main.tf file I use for my terraform configuration. You create that in the same directory as terraform.
#
# ```json
# provider "aws" {
#  access_key         = "test"
#  secret_key         = "test"
#  region           = "us-east-1"
#  s3_use_path_style      = true
#  skip_credentials_validation = true
#  skip_metadata_api_check   = true
#  skip_requesting_account_id = true
#  endpoints {
#  s3 = "http://localhost:4566"
#  # Add other services as needed
#  }
# }
#
# ```
# After you created the main.tf file, which I would copy exactly an experiment later. Run the tflocal init command in that folder where you created main.tf. This will attempt to initialize it in your local environment.
#
# The last step after running tflocal init and tflocal apply, is to make sure it works. Update your config and credentials file to point to your local env.
#
# hashtag#AWS CLI is wrapped with 'awslocal' which points to your localhost.
#
# You will likely need to set your environment variables in PATH, to where you install the .exe. Follow the instructions on these pages below.
#
# *Don't forget to use Docker Scout Analysis on hashtag#images.
#
# **Note: You need to match your .env with your main.tf. You can then run 'localstack start' and see logs as you create resources.
# ------
#
# LocalStack Installation:
# https://lnkd.in/ee7zZs8b
#
# Install LocalStack with Docker Extension:
# https://lnkd.in/emEeXrzd
#
# Docker Extension for LocalStack:
# https://lnkd.in/eNWKZQPS
#
# Amazon Web Services (AWS) documentation for testing infrastructure with hashtag#LocalStack and hashtag#Terraform tests:
# https://lnkd.in/eipazngB

# %% [markdown]
# Practice AWS Development Without Costs! 🎁
# Section 1: Introduction
# Header: Merry Thanksgiving! 🎉 Here's Your Present!
# Text:
# Tired of worrying about AWS charges while learning or practicing? There's a way to emulate AWS locally without breaking the bank!
#
# Visual: Thanksgiving-themed graphic (e.g., a turkey with a laptop).
#
# Section 2: Why It Matters
# Header: Why Simulate AWS Locally?
# Text:
# ✔️ Develop and test without charges.
# ✔️ Perfect for scenario-based learning.
# ✔️ Works with tools like Docker, LocalStack, and Terraform.
#
# Visual: Icon set for Docker, LocalStack, and Terraform.
#
# Section 3: The Tools You Need
# Header: Tools to Get Started
# Text:
# 🛠️ Docker (with LocalStack extension).
# 🛠️ LocalStack (for AWS emulation).
# 🛠️ Terraform (for infrastructure as code).
#
# Visual: Simple flowchart showing the relationship between Docker, LocalStack, and Terraform.
#
# Section 4: How It Works
# Header: How Does It Work?
# Text:
# 1️⃣ Emulate AWS services locally (e.g., S3).
# 2️⃣ Configure endpoints to point to your local machine:
# s3 = "http://localhost:4566"
# 3️⃣ Use Terraform (main.tf) to automate infrastructure.
#
# Visual: Code snippet styled box.
#
# Section 5: Key Steps
# Header: Steps to Set Up
# Text:
# 1️⃣ Install LocalStack and Docker Desktop.
# 2️⃣ Create and configure a main.tf file.
# 3️⃣ Run commands: tflocal init and tflocal apply.
#
# Visual: Simple step-by-step diagram with icons for each tool.
#
# Section 6: Helpful Resources
# Header: Helpful Links
# Text:
# 📌 LocalStack Installation Guide
# 📌 Docker Extension for LocalStack
# 📌 Terraform Local Testing Docs
#
# Visual: Icons for documentation.
#
# Closing
# Header: Start Building Locally Today! 🚀
# Text:
# Let’s make AWS development more accessible for everyone. Share your experience or tips below!
#
# Visual: Thank-you note with AWS/cloud-themed background.

# %%
{
    "FunctionName": "my-function",
    "FunctionArn": "arn:aws:lambda:us-east-1:000000000000:function:my-function",
    "Runtime": "python3.9",
    "Role": "arn:aws:iam::000000000000:role/execution_role",
    "Handler": "lambda_function.lambda_handler",
    "CodeSize": 239,
    "Description": "",
    "Timeout": 3,
    "MemorySize": 128,
    "LastModified": "2024-11-30T02:30:43.359048+0000",
    "CodeSha256": "n6WVYAAKSP/Zbf9Xc0NjEFoKoUZs02SIWWoS3n9nAlU=",
    "Version": "$LATEST",
    "TracingConfig": {
        "Mode": "PassThrough"
    },
    "RevisionId": "21e2a14c-83c1-4da7-8742-82bedfa18311",
    "State": "Pending",
    "StateReason": "The function is being created.",
    "StateReasonCode": "Creating",
    "PackageType": "Zip",
    "Architectures": [
        "x86_64"
    ],
    "EphemeralStorage": {
        "Size": 512
    },
    "SnapStart": {
        "ApplyOn": "None",
        "OptimizationStatus": "Off"
    },
    "RuntimeVersionConfig": {
        "RuntimeVersionArn": "arn:aws:lambda:us-east-1::runtime:8eeff65f6809a3ce81507fe733fe09b835899b99481ba22fd75b5a7338290ec1"
    },
    "LoggingConfig": {
        "LogFormat": "Text",
        "LogGroup": "/aws/lambda/my-function"
    }
}

# %%
$ awslocal lambda invoke --function-name my-function output.txt
{
    "StatusCode": 200,
    "FunctionError": "Unhandled",
    "ExecutedVersion": "$LATEST"
}

# %%
Ready.
2024-11-30T01:33:41.243  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.CreateBucket => 200
2024-11-30T02:07:26.536  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListObjects => 200
2024-11-30T02:07:26.854  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.GetObject => 404 (NoSuchKey)
2024-11-30T02:11:54.244  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListBuckets => 200
2024-11-30T02:11:54.545  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListObjects => 404 (NoSuchBucket)
2024-11-30T02:15:21.177  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.PutObject => 200
2024-11-30T02:15:34.316  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListObjectsV2 => 200
2024-11-30T02:19:41.146  INFO --- [et.reactor-0] localstack.utils.bootstrap : Execution of "require" took 1465.99ms
2024-11-30T02:19:41.295  INFO --- [et.reactor-0] localstack.request.aws     : AWS dynamodb.CreateTable => 200
2024-11-30T02:22:33.023  INFO --- [et.reactor-1] localstack.request.aws     : AWS dynamodb.CreateTable => 400 (ResourceInUseException)
2024-11-30T02:22:54.701  INFO --- [et.reactor-1] localstack.request.aws     : AWS dynamodb.ListTables => 200
2024-11-30T02:29:51.642  INFO --- [et.reactor-1] localstack.request.aws     : AWS lambda.CreateFunction => 400 (ValidationException)
2024-11-30T02:30:43.359  INFO --- [et.reactor-1] localstack.request.aws     : AWS lambda.CreateFunction => 201
2024-11-30T02:34:41.279  INFO --- [et.reactor-1] l.u.container_networking   : Determined main container network: bridge
2024-11-30T02:34:41.287  INFO --- [et.reactor-1] l.u.container_networking   : Determined main container target IP: 172.17.0.3
2024-11-30T02:34:42.152  WARN --- [et.reactor-0] l.s.l.i.executor_endpoint  : Execution environment startup failed: {"errorMessage": "Syntax error in module 'lambda_function': unmatched '}' (lambda_function.py, line 6)", "errorType": "Runtime.UserCodeSyntaxError", "requestId": "", "stackTrace": ["  File \"/var/task/lambda_function.py\" Line 6\n    }"]}
2024-11-30T02:34:42.153  INFO --- [et.reactor-0] localstack.request.http    : POST /_localstack_lambda/ecf3eef84f01cad427497687a6de2169/status/ecf3eef84f01cad427497687a6de2169/error => 202
2024-11-30T02:34:42.153  WARN --- [et.reactor-1] l.s.l.i.execution_environm : Failed to start execution environment ecf3eef84f01cad427497687a6de2169: Environment startup failed
2024-11-30T02:34:42.153  WARN --- [et.reactor-1] l.s.l.i.execution_environm : Execution environment ecf3eef84f01cad427497687a6de2169 for function arn:aws:lambda:us-east-1:000000000000:function:my-function:$LATEST failed during startup. Check for errors during the startup of your Lambda function.
2024-11-30T02:34:42.453  INFO --- [et.reactor-1] localstack.request.aws     : AWS lambda.Invoke => 200
2024-11-30T02:37:04.728  INFO --- [et.reactor-1] localstack.request.http    : GET / => 200
2024-11-30T02:37:17.451  INFO --- [et.reactor-1] localstack.request.aws     : AWS s3.ListBuckets => 200

# %%
Ready.
2024-11-30T01:33:41.243  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.CreateBucket => 200
2024-11-30T02:07:26.536  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListObjects => 200
2024-11-30T02:07:26.854  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.GetObject => 404 (NoSuchKey)
2024-11-30T02:11:54.244  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListBuckets => 200
2024-11-30T02:11:54.545  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListObjects => 404 (NoSuchBucket)
2024-11-30T02:15:21.177  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.PutObject => 200
2024-11-30T02:15:34.316  INFO --- [et.reactor-0] localstack.request.aws     : AWS s3.ListObjectsV2 => 200
2024-11-30T02:19:41.146  INFO --- [et.reactor-0] localstack.utils.bootstrap : Execution of "require" took 1465.99ms
2024-11-30T02:19:41.295  INFO --- [et.reactor-0] localstack.request.aws     : AWS dynamodb.CreateTable => 200
2024-11-30T02:22:33.023  INFO --- [et.reactor-1] localstack.request.aws     : AWS dynamodb.CreateTable => 400 (ResourceInUseException)
2024-11-30T02:22:54.701  INFO --- [et.reactor-1] localstack.request.aws     : AWS dynamodb.ListTables => 200
2024-11-30T02:29:51.642  INFO --- [et.reactor-1] localstack.request.aws     : AWS lambda.CreateFunction => 400 (ValidationException)
2024-11-30T02:30:43.359  INFO --- [et.reactor-1] localstack.request.aws     : AWS lambda.CreateFunction => 201
2024-11-30T02:34:41.279  INFO --- [et.reactor-1] l.u.container_networking   : Determined main container network: bridge
2024-11-30T02:34:41.287  INFO --- [et.reactor-1] l.u.container_networking   : Determined main container target IP: 172.17.0.3
2024-11-30T02:34:42.152  WARN --- [et.reactor-0] l.s.l.i.executor_endpoint  : Execution environment startup failed: {"errorMessage": "Syntax error in module 'lambda_function': unmatched '}' (lambda_function.py, line 6)", "errorType": "Runtime.UserCodeSyntaxError", "requestId": "", "stackTrace": ["  File \"/var/task/lambda_function.py\" Line 6\n    }"]}
2024-11-30T02:34:42.153  INFO --- [et.reactor-0] localstack.request.http    : POST /_localstack_lambda/ecf3eef84f01cad427497687a6de2169/status/ecf3eef84f01cad427497687a6de2169/error => 202
2024-11-30T02:34:42.153  WARN --- [et.reactor-1] l.s.l.i.execution_environm : Failed to start execution environment ecf3eef84f01cad427497687a6de2169: Environment startup failed
2024-11-30T02:34:42.153  WARN --- [et.reactor-1] l.s.l.i.execution_environm : Execution environment ecf3eef84f01cad427497687a6de2169 for function arn:aws:lambda:us-east-1:000000000000:function:my-function:$LATEST failed during startup. Check for errors during the startup of your Lambda function.
2024-11-30T02:34:42.453  INFO --- [et.reactor-1] localstack.request.aws     : AWS lambda.Invoke => 200
2024-11-30T02:37:04.728  INFO --- [et.reactor-1] localstack.request.http    : GET / => 200
2024-11-30T02:37:17.451  INFO --- [et.reactor-1] localstack.request.aws     : AWS s3.ListBuckets => 200
2024-11-30T02:59:38.285  INFO --- [et.reactor-1] localstack.request.aws     : AWS s3.ListBuckets => 200
2024-11-30T02:59:50.924  INFO --- [et.reactor-1] localstack.request.aws     : AWS s3.ListBuckets => 200
Localstack runtime received signal 15
2024-11-30T03:01:36.832  INFO --- [ime-Shutdown] l.runtime.shutdown         : [shutdown] Stopping all services

LocalStack version: 4.0.3.dev25
LocalStack build date: 2024-11-29
LocalStack build git hash: 892eb4d06

Ready.

# %% [markdown]
# obsidian://open?vault=AWS%20Services&file=Terraform_Localstack_Readable

# %% [markdown]
# ![image.png](attachment:image.png)
